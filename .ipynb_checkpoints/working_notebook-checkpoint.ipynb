# %%
# !rm ./voc_train.pkl
# !rm ./voc_valid.pkl

#!python3 train.py -c config.json
# !python3 train_busboat.py -c config_bb.json
# Out:
# Using TensorFlow backend.
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# ...

# %%
#Delete .pkl files when evaluating on new datasets
# !rm ./voc_valid.pkl
# !python evaluate.py -c config_bbmixup.json
# Out:
# Using TensorFlow backend.
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# ...

# %%
# !python predict.py -c config.json -i ./test_images/cow.jpg
# Out:
# Using TensorFlow backend.
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/henri_tomas/miniconda3/envs/keras1/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
# ...

# %%
# !python gen_anchors.py -c config_busboat.json
# Out:
# /home/henri_tomas/projects/mixup/keras-yolo3/data/train/JPEGImages/000005.jpg
# /home/henri_tomas/projects/mixup/keras-yolo3/data/train/JPEGImages/000035.jpg
# /home/henri_tomas/projects/mixup/keras-yolo3/data/train/JPEGImages/000044.jpg
# /home/henri_tomas/projects/mixup/keras-yolo3/data/train/JPEGImages/000047.jpg
# /home/henri_tomas/projects/mixup/keras-yolo3/data/train/JPEGImages/000050.jpg
# /home/henri_tomas/projects/mixup/keras-yolo3/data/train/JPEGImages/000063.jpg
# /home/henri_tomas/projects/mixup/keras-yolo3/data/train/JPEGImages/000089.jpg
# /home/henri_tomas/projects/mixup/keras-yolo3/data/train/JPEGImages/000093.jpg
# /home/henri_tomas/projects/mixup/keras-yolo3/data/train/JPEGImages/000101.jpg
# /home/henri_tomas/projects/mixup/keras-yolo3/data/train/JPEGImages/000107.jpg
# /home/henri_tomas/projects/mixup/keras-yolo3/data/train/JPEGImages/000112.jpg
# /home/henri_tomas/projects/mixup/keras-yolo3/data/train/JPEGImages/000147.jpg
# ...
